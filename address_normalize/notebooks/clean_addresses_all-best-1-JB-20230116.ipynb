# %% [markdown]
# Clean all the addresses

# %%
import numpy as np
import pandas as pd
import re
import usaddress

from address_normalize.model import Model
from address_normalize.paths import DATA_DIR
from address_normalize.utils import jaccard_similarity, load_corpus

# %%
model = Model()

# %%
raw_dir = DATA_DIR / 'raw'

files = list(raw_dir.glob('Master Project Address List*.xlsx'))
files.sort()

file_path = files[-1]

data = pd.read_excel(file_path, sheet_name=['Phase_I', 'Phase_II', 'Phase_III'])

corpus_dict = load_corpus(DATA_DIR / 'corpus_dict.pkl')
print(len(corpus_dict))
# Out:
# 3802

# %%
phase1_df = data['Phase_I']
pending_df = pd.concat([data['Phase_II'], data['Phase_III']])

# %%
print(phase1_df.shape)
phase1_df.head()
# Out:
# (2024, 34)
#    OBJECTID   REF  ESITEID Build Phase                ADDRESS  \
# 0      1547  1547    78274     Phase 1       114 S BINGHAM ST
# 1      1316  1316   139583     Phase 1  1896 OLD JERUSALEM RD
# 2       189   189   184321     Phase 1           14 CHURCH ST
# 3      1382  1382    78171     Phase 1             24 PARK LN
# 4       328   328   216370     Phase 1          156 MIDDLE RD
#
#             E911 ADDRESS             OWNER 1            OWNER 2  \
# 0       114 S BINGHAM ST   114 S BINGHAM LLC         (QUINTTUS)
# 1  1896 OLD JERUSALEM RD        80 GOATS INC
# 2           14 CHURCH ST        ABBOTT JACOB  ABBOTT KAREN LYNN
# 3             24 PARK Ln  ABEL WILLA & SIMON
# 4          156 MIDDLE RD   ACCIAVIATTI BRUCE      SMITH COLLEEN
#
#      GRAND LIST ADDRESS  GRAND LIST = ADDRESS  ... COL_R COL_S  COL_T COL_U  \
# 0        15  ASHLAND AVE                    N  ...   NaN   NaN    NaN   NaN
# 1  2001 OLD JERUSALEM RD                    N  ...   NaN   NaN    NaN   NaN
# 2           14 CHURCH ST                    Y  ...   NaN   NaN    NaN   NaN
# 3             24 PARK LN                    Y  ...   NaN   NaN    NaN   NaN
# 4          156 MIDDLE RD                    Y  ...   1.0   NaN    NaN   NaN
#
#   COL_V COL_W COL_X  COL_Y    GNS Area Construction Status
# 0   NaN   NaN   NaN    NaN         NaN            Included
# 1   NaN   NaN   NaN    1.0         NaN            Included
# 2   NaN   NaN   NaN    NaN         NaN            Included
# 3   NaN   NaN   NaN    NaN  GoNetSpeed            Excluded
# 4   NaN   NaN   NaN    1.0         NaN            Included
#
# [5 rows x 34 columns]

# %%
print(pending_df.shape)
pending_df.head()
# Out:
# (7465, 12)
#    REF  ESITEID              Address       Town    ZIP     PON Boundary  \
# 0    1   264978         160 GREEN ST  VERGENNES  05491  LCC VERGENNES-3
# 1    2   265443        26 THOMAS CIR  VERGENNES  05491  LCC VERGENNES-2
# 2    3   265008         22 SUNSET DR  VERGENNES  05491  LCC VERGENNES-3
# 3    4   184727       99 GRISWOLD LN     ORWELL  05760     LCC ORWELL-5
# 4    5   139558  411 MOUNTAINVIEW DR  LEICESTER  05733  LCC LEICESTER-5
#
#         Status  Service Speed  Eligible        LAT       LONG Build Phase
# 0       Served  Served 100/20       NaN  44.161107 -73.245427    Phase II
# 1       Served  Served 100/20       NaN  44.156948 -73.245608    Phase II
# 2       Served  Served 100/20       NaN  44.160163 -73.245543    Phase II
# 3  Underserved     Served 4/1  Eligible  43.815731 -73.247273    Phase II
# 4       Served  Served 100/20       NaN  43.878902 -73.070688    Phase II

# %%
phase1_sents = phase1_df['ADDRESS'].tolist()
pending_phase_sents = pending_df['Address'].tolist()
print(phase1_sents[:10])
print(pending_phase_sents[:10])
# Out:
# ['114 S BINGHAM ST', '1896 OLD JERUSALEM RD', '14 CHURCH ST', '24 PARK LN', '156 MIDDLE RD', '82 OLIVER HOWE CT', '112 SCHOOL RD', '289 CROSS RD', '466 N ORWELL RD', '79 LEMON FAIR RD']
# ['160 GREEN ST', '26 THOMAS CIR', '22 SUNSET DR', '99 GRISWOLD LN', '411 MOUNTAINVIEW DR', '204 WALKER RD', '4215 SAND RD', '0 SWALLOW DR', '5592 US ROUTE 7', '178 HORTON RD']

# %%
phase1_matches = model(phase1_sents)

phase1_matches_df = pd.DataFrame(phase1_matches, columns=['phase_1_address', 'score', 'e911_address'])
phase1_matches_df.to_csv(DATA_DIR / 'processed' / 'phase1_matches_df.csv', index=False)

phase1_matches_df.sort_values(by='score', ascending=False).head(25)
# Out:
# No address number match for 6335 vt route 22a
# No address number match for 6326 vt route 22a
# No address number match for 4823 vt route 74 w
# No address number match for 4821 vt route 74 w
# No address number match for 4831 vt route 74 w
# No address number match for 4718 vt route 74 w
# No address number match for 5866 vt route 22a
# No address number match for 3597 vt route 74 w
# No address number match for 3593 vt route 74 w
# No address number match for 5834 vt route 22a
# No address number match for 3591 vt route 74 w
# No address number match for 5625 vt route 22a
# No address number match for 2973 hemenway hill rd
# No address number match for 3474 richville rd
# No address number match for 3539 richville rd
# No address number match for 1358 n orwell rd
# No address number match for 1990 richville rd
# No address number match for 1142 school st
# No address number match for 1300 smith st
# No address number match for 3121 watch point rd
# No address number match for 2390 leland rd
# No address number match for 3327 vt route 22a
# No address number match for 2339 smith st
# No address number match for 2361 smith st
# No address number match for 2002 cutting hill rd
# No address number match for 1695 shacksboro rd
# No address number match for 2880 smith st
# No address number match for 2793 vt route 22a
# No address number match for 1098 leland rd
# No address number match for 1869 lake st
# No address number match for 2670 shacksboro rd
# No address number match for 5842 vt route 30
# No address number match for 5672 vt route 30
# No address number match for 978 wooster rd
# No address number match for 1092 quiet valley rd
# No address number match for 2230 vt route 74 e
# No address number match for 2222 happy valley rd
# No address number match for 4524 vt route 74 e
# No address number match for 477 doolittle rd
# No address number match for 1493 shard villa rd
# No address number match for 3354 vt route 30
# No address number match for 0 n bingham st
# No address number match for 2819 south st ext
# No address number match for 2749 south st ext
# No address number match for 0 morse rd
# No address number match for 2143 west st
# No address number match for 2314 west st
# No address number match for 2371 west st
# No address number match for 2172 vt route 125
#            phase_1_address  score           e911_address
# 0         114 s bingham st    1.0       114 S BINGHAM ST
# 756          410 delong ln    1.0          410 DELONG LN
# 762        19 n bingham st    1.0        19 N BINGHAM ST
# 761           125 morse rd    1.0           125 MORSE RD
# 760         1402 sperry rd    1.0         1402 SPERRY RD
# 759       1027 halladay rd    1.0       1027 HALLADAY RD
# 758    732 n cream hill rd    1.0    732 N CREAM HILL RD
# 757      685 lapham bay rd    1.0      685 LAPHAM BAY RD
# 755          241 school st    1.0          241 SCHOOL ST
# 764    620 n cream hill rd    1.0    620 N CREAM HILL RD
# 754            97 brown rd    1.0            97 BROWN RD
# 753        142 bilodeau rd    1.0        142 BILODEAU RD
# 752      740 shacksboro rd    1.0      740 SHACKSBORO RD
# 751         1874 morgan rd    1.0         1874 MORGAN RD
# 750     248 old foundry rd    1.0     248 OLD FOUNDRY RD
# 749            227 main st    1.0            227 MAIN ST
# 763     3122 lapham bay rd    1.0     3122 LAPHAM BAY RD
# 765         50 edgewood ln    1.0         50 EDGEWOOD Ln
# 747     2413 shacksboro rd    1.0     2413 SHACKSBORO RD
# 774  2615 old jerusalem rd    1.0  2615 OLD JERUSALEM RD
# 780          2182 morse rd    1.0          2182 MORSE RD
# 779    2513 w salisbury rd    1.0    2513 W SALISBURY RD
# 778       68 shacksboro rd    1.0       68 SHACKSBORO RD
# 777          11 sampson rd    1.0          11 SAMPSON RD
# 776          109 church st    1.0          109 CHURCH ST

# %%
pending_phase = model(pending_phase_sents)

pending_phase_df = pd.DataFrame(pending_phase, columns=['address', 'score', 'e911_address'])
pending_phase_df.to_csv(DATA_DIR / 'processed' / 'pending_phase_df.csv', index=False)

pending_phase_df.sort_values(by='score', ascending=False).head(25)
# Out:
# No address number match for 0 swallow dr
# No address number match for 1314 little chicago rd
# No address number match for 2680 maple st
# No address number match for 5340 sand rd
# No address number match for 0 keewaydin way
# No address number match for 3675 monkton rd
# No address number match for 3014 hawkins rd
# No address number match for 3064 plank rd
# No address number match for 5075 us route 7
# No address number match for 0 lake dunmore rd
# No address number match for 1389 hooker rd
# No address number match for 0 lake dunmore rd
# No address number match for 2819 maple st
# No address number match for 0 lake dunmore rd
# No address number match for 1424 hooker rd
# No address number match for 787 kingsland bay state park rd
# No address number match for 1522 maple st
# No address number match for 3208 us route 7
# No address number match for 0 lake dunmore rd
# No address number match for 3778 monkton rd
# No address number match for 4067 monkton rd
# No address number match for 7569 ethan allen hwy
# No address number match for 3572 lake dunmore rd
# No address number match for 2779 us route 7
# No address number match for 0 keewaydin way
# No address number match for 2063 west shore rd
# No address number match for 0 chickadee ave
# No address number match for 0 lake dunmore rd
# No address number match for 3982 us route 7
# No address number match for 5093 us route 7
# No address number match for 7263 ethan allen hwy
# No address number match for 7519 ethan allen hwy
# No address number match for 2266 us route 7
# No address number match for 0 canal st
# No address number match for 4447 us route 7
# No address number match for 5091 us route 7
# No address number match for 3123 maple st
# No address number match for 0 keewaydin way
# No address number match for 3116 silver lake rd
# No address number match for 3913 monkton rd
# No address number match for 2660 monkton rd
# No address number match for 0 keewaydin way
# No address number match for 7495 ethan allen hwy
# No address number match for 0 woodpecker ave
# No address number match for 1730 silver lake rd
# No address number match for 0 lake dunmore rd
# No address number match for 0 lake dunmore rd
# No address number match for 4279 sand rd
# No address number match for 4628 sand rd
# No address number match for 0 lake dunmore rd
# No address number match for 1807 us route 7
# No address number match for 0 keewaydin way
# No address number match for 0 diamond is
# No address number match for 2685 leicester whiting rd
# No address number match for 2416 leicester whiting rd
# No address number match for 4176 sand rd
# No address number match for 0 keewaydin way
# No address number match for 1990 lake dunmore rd
# No address number match for 0 lake dunmore rd
# No address number match for 2095 lake dunmore rd
# No address number match for 2660 us route 7
# No address number match for 5420 sand rd
# No address number match for 0 keewaydin way
# No address number match for 1611 lake dunmore rd
# No address number match for 0 lake dunmore rd
# No address number match for 0 lake dunmore rd
# No address number match for 5030 us route 7
# No address number match for 0 keewaydin way
# No address number match for 2097 lake dunmore rd
# No address number match for 0 owls ave
# No address number match for 3059 maple st
# No address number match for 0 lake dunmore rd
# No address number match for 0 lake dunmore rd
# No address number match for 0 keewaydin way
# No address number match for 7547 ethan allen hwy
# No address number match for 3077 shellhouse mountain rd
# No address number match for 1588 lake dunmore rd
# No address number match for 0 keewaydin way
# No address number match for 0 keewaydin way
# No address number match for 0 lake dunmore rd
# No address number match for 0 hawkins rd
# No address number match for 0 parker ln
# No address number match for 1406 little chicago rd
# No address number match for 0 lake dunmore rd
# No address number match for 0 keewaydin way
# No address number match for 0 keewaydin way
# No address number match for 2942 monkton rd
# No address number match for 1992 lake dunmore rd
# No address number match for 0 lake dunmore rd
# No address number match for 2386 us route 7
# No address number match for 5359 us route 7
# No address number match for 2933 us route 7
# No address number match for 0 canal st
# No address number match for 0 lake dunmore rd
# No address number match for 1611 us route 7
# No address number match for 3554 monkton rd
# No address number match for 0 keewaydin way
# No address number match for 1486 us route 7 n
# No address number match for 2267 river rd
# No address number match for 561 airport rd
# No address number match for 1618 case st
# No address number match for 1660 ethan allen hwy
# No address number match for 2377 us route 7 s
# No address number match for 1522 us route 7 n
# No address number match for 0 adirondack vw
# No address number match for 1300 lincoln rd
# No address number match for 4290 vt route 125
# No address number match for 3005 upper plains rd
# No address number match for 2260 upper plains rd
# No address number match for 2759 river rd
# No address number match for 1480 us route 7 n
# No address number match for 3929 lincoln rd
# No address number match for 3753 us route 7 s
# No address number match for 4289 vt route 125
# No address number match for 4026 munger st
# No address number match for 5317 case st
# No address number match for 2896 us route 7 s
# No address number match for 4343 vt route 125
# No address number match for 4041 lincoln rd
# No address number match for 4311 vt route 125
# No address number match for 3624 steam mill rd
# No address number match for 2122 case st
# No address number match for 1668 hunt rd
# No address number match for 2816 upper plains rd
# No address number match for 4301 case st
# No address number match for 4274 vt route 125
# No address number match for 1522 lincoln rd
# No address number match for 0 case st
# No address number match for 4260 vt route 125
# No address number match for 1389 upper plains rd
# No address number match for 1314 lincoln rd
# No address number match for 2122 upper plains rd
# No address number match for 2145 us route 7 s
# No address number match for 3894 south st
# No address number match for 4023 case st
# No address number match for 4478 munger st
# No address number match for 4453 vt route 125
# No address number match for 3461 vt route 125
# No address number match for 1336 dog team rd
# No address number match for 1182 us route 7
# No address number match for 2491 upper plains rd
# No address number match for 3280 lincoln rd
#                    address  score          e911_address
# 0             160 green st    1.0          160 GREEN St
# 6231      44 birchard park    1.0      44 BIRCHARD PARK
# 6225       527 buttolph dr    1.0       527 BUTTOLPH Dr
# 6226  2776 upper plains rd    1.0  2776 UPPER PLAINS RD
# 3491        1646 hooker rd    1.0        1646 HOOKER RD
# 3490      404 underwood ln    1.0      404 UNDERWOOD LN
# 6227  194 billings farm rd    1.0  194 BILLINGS FARM RD
# 3488   329 mountainview dr    1.0   329 MOUNTAINVIEW DR
# 6228         106 s main st    1.0         106 S MAIN St
# 3484   145 lake dunmore rd    1.0   145 LAKE DUNMORE RD
# 6234         464 e main st    1.0         464 E MAIN St
# 3483          1040 sand rd    1.0          1040 SAND RD
# 6232         68 s ridge dr    1.0         68 S RIDGE Dr
# 3481         3 crescent dr    1.0         3 CRESCENT Dr
# 3480         1200 route 66    1.0         1200 ROUTE 66
# 3479       3319 monkton rd    1.0       3319 MONKTON RD
# 3478       652 botsford rd    1.0       652 BOTSFORD RD
# 3476         2996 maple st    1.0         2996 MAPLE St
# 3495          1 hopkins rd    1.0          1 HOPKINS RD
# 3497        151 s maple st    1.0        151 S MAPLE St
# 3498           6 panton rd    1.0           6 PANTON RD
# 6218          7 meadow way    1.0          7 MEADOW WAY
# 3517       197 lakeview dr    1.0       197 LAKEVIEW DR
# 6213         422 s main st    1.0         422 S MAIN St
# 6214        211 cottage ln    1.0        211 COTTAGE Ln
