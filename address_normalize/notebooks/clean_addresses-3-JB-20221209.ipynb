# %% [markdown]
# Parse the addresses, then have a sequential matching mechanism:
# 1. First match on number
# 2. Then out of that set match on closes street

# %%
from sentence_transformers import SentenceTransformer
from sentence_transformers.util import semantic_search

# %%
import numpy as np
import pandas as pd
import re
import usaddress


from address_normalize.paths import DATA_DIR

raw_dir = DATA_DIR / 'raw'

files = list(raw_dir.glob('Master Project Address List*.xlsx'))
files.sort()

file_path = files[-1]

data = pd.read_excel(file_path, sheet_name=['E911 Data', 'Phase_I', 'Phase_II', 'Phase_III'])

df_e911 = data['E911 Data']
main_df = data['Phase_I']

# %%
main_df.head()
# Out:
#    OBJECTID   REF  ESITEID Build Phase                ADDRESS  \
# 0      1547  1547    78274     Phase 1       114 S BINGHAM ST
# 1      1316  1316   139583     Phase 1  1896 OLD JERUSALEM RD
# 2       189   189   184321     Phase 1           14 CHURCH ST
# 3      1382  1382    78171     Phase 1             24 PARK LN
# 4       328   328   216370     Phase 1          156 MIDDLE RD
#
#             E911 ADDRESS             OWNER 1            OWNER 2  \
# 0       114 S BINGHAM ST   114 S BINGHAM LLC         (QUINTTUS)
# 1  1896 OLD JERUSALEM RD        80 GOATS INC
# 2           14 CHURCH ST        ABBOTT JACOB  ABBOTT KAREN LYNN
# 3             24 PARK Ln  ABEL WILLA & SIMON
# 4          156 MIDDLE RD   ACCIAVIATTI BRUCE      SMITH COLLEEN
#
#      GRAND LIST ADDRESS  GRAND LIST = ADDRESS  ... COL_R COL_S  COL_T COL_U  \
# 0        15  ASHLAND AVE                    N  ...   NaN   NaN    NaN   NaN
# 1  2001 OLD JERUSALEM RD                    N  ...   NaN   NaN    NaN   NaN
# 2           14 CHURCH ST                    Y  ...   NaN   NaN    NaN   NaN
# 3             24 PARK LN                    Y  ...   NaN   NaN    NaN   NaN
# 4          156 MIDDLE RD                    Y  ...   1.0   NaN    NaN   NaN
#
#   COL_V COL_W COL_X  COL_Y    GNS Area Construction Status
# 0   NaN   NaN   NaN    NaN         NaN            Included
# 1   NaN   NaN   NaN    1.0         NaN            Included
# 2   NaN   NaN   NaN    NaN         NaN            Included
# 3   NaN   NaN   NaN    NaN  GoNetSpeed            Excluded
# 4   NaN   NaN   NaN    1.0         NaN            Included
#
# [5 rows x 34 columns]

# %%
df_e911['E911 ADDRESS']
# Out:
# 0                32 BOOTH WOODS
# 1                        8 E St
# 2                  73 SCHOOL St
# 3                   206 MAIN St
# 4                   224 MAIN St
#                   ...
# 17430    574 ROBEROUTE YOUNG RD
# 17431
# 17432          151 VT R0UTE 116
# 17433         71 SPRING HILL Ln
# 17434               14 TATRO RD
# Name: E911 ADDRESS, Length: 17435, dtype: object

# %%
sents = df_e911['E911 ADDRESS'].tolist()

# %%
df_e911.head()
# Out:
#    OBJECTID_1    E911 ADDRESS  OBJECTID                   OWNER 1  \
# 0           1  32 BOOTH WOODS  18621475             STAPLES WAYNE
# 1           2          8 E St  18621476      LINCOLN GERONIMO LLC
# 2           3    73 SCHOOL St  18621477             WHITNEY GRACE
# 3           4     206 MAIN St  18621478  SMALLEST CITY HOUSING LP
# 4           5     224 MAIN St  18621479  SMALLEST CITY HOUSING LP
#
#           OWNER 2   GRAND LIST ADDRESS  GRAND LIST CITY GRAND LIST STATE  \
# 0  MCENTEE SHEILA        32 BOOTH WOODS       VERGENNES               VT
# 1                  1341 ARNOLD BAY ROAD          PANTON               VT
# 2                            PO BOX 541    CROTON FALLS               NY
# 3                            PO BOX 156       VERGENNES               VT
# 4                            PO BOX 156       VERGENNES               VT
#
#   GRAND LIST ZIPCODE           SPAN  ... GLVAL_HS GLVAL_NR CRHOUSPCT  \
# 0              05491  663-210-10001  ...     1837        0         0
# 1              05491  663-210-10002  ...        0     1755         0
# 2              10519  663-210-10003  ...        0     2213         0
# 3              05491  663-210-10004  ...        0     2988         0
# 4              05491  663-210-10005  ...        0     3314         0
#
#   MUNGL1PCT  AOEGL_HS  AOEGL_NR   SHAPESTAre  SHAPESTLen Shape_Length  \
# 0      1837      1837         0  1231.173523  145.763504   145.763504
# 1      1755         0      1755   532.200386   92.414705    92.414705
# 2      2213         0      2213   880.616867  118.855189   118.855189
# 3      3284         0      2988   709.602440  109.360601   109.360601
# 4      3682         0      3314  1242.662354  167.708389   167.708389
#
#     Shape_Area
# 0  1231.173529
# 1   532.200394
# 2   880.616861
# 3   709.602436
# 4  1242.662357
#
# [5 rows x 60 columns]

# %%
corpus_sents = df_e911['E911 ADDRESS'].tolist()
query_sents = main_df['ADDRESS'].tolist()
print(corpus_sents[:10])
print(query_sents[:10])
# Out:
# ['32 BOOTH WOODS', '8 E St', '73 SCHOOL St', '206 MAIN St', '224 MAIN St', '38 W St', '23 SUNSET Dr', 'PANTON RD', '67 NEW HAVEN RD', 'PANTON RD']
# ['114 S BINGHAM ST', '1896 OLD JERUSALEM RD', '14 CHURCH ST', '24 PARK LN', '156 MIDDLE RD', '82 OLIVER HOWE CT', '112 SCHOOL RD', '289 CROSS RD', '466 N ORWELL RD', '79 LEMON FAIR RD']

# %%
usaddress.tag(corpus_sents[0])[0]
# Out:
# OrderedDict([('AddressNumber', '32'), ('StreetName', 'BOOTH WOODS')])

# %%
test = '3407A&B N 116 RD'
re.match(r'(\d+)(.*)', test).groups()
# Out:
# ('3407', 'A&B N 116 RD')

# %%
def address_parser(address):
    address = address.strip().lower()
    try:
        parsed = usaddress.tag(address)[0]
        address_number = parsed['AddressNumber']
        if 'AddressNumber' not in parsed:
            address_number = ''
    except:
        # hack for now, doesn't really work, but will for my purpose
        try:
            address_number, street_name = re.match(r'(\d+)(.*)', address).groups()
        except:
            address_number = ''
            street_name = address

    street_name = address.replace(address_number, '')
    return address_number.strip(), street_name.strip()

# %%
corpus_dict = {}

for address in corpus_sents:
    if address.strip() != '':
        an, street_name = address_parser(address)
        if an in corpus_dict:
            if street_name not in corpus_dict:
                corpus_dict[an]['street_names'].append(street_name)
        else:
            corpus_dict[an] = {}
            corpus_dict[an]['street_names'] = [street_name]

# %%
model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')

# %%
for address_number in corpus_dict:
    # encoding dupes, but not big enough to matter
    corpus_dict[address_number]['embeddings'] = model.encode(corpus_dict[address_number]['street_names'])

# %%
print(len(corpus_dict))
# Out:
# 3802

# %%
corpus_dict['8']['embeddings']
# Out:
# array([[-5.2162834e-02, -6.8031766e-02, -9.5437237e-05, ...,
#          2.8231055e-02, -2.5067197e-02, -4.1093454e-02],
#        [-4.5955621e-02,  5.6968041e-02,  2.8331166e-02, ...,
#          1.6828598e-02,  1.1414270e-02, -1.3194392e-02],
#        [ 5.6897841e-02, -8.1873097e-02,  1.5928879e-02, ...,
#          5.7965655e-02,  1.6379334e-02, -9.5717851e-03],
#        ...,
#        [-5.7484242e-03, -2.5470851e-02,  2.7082184e-02, ...,
#          2.6107650e-02, -6.6857100e-02, -2.9040694e-02],
#        [-5.2660540e-02,  3.8511250e-02, -3.4262054e-03, ...,
#          1.5467446e-02, -4.5267146e-02, -2.3198834e-02],
#        [ 5.4433313e-03,  6.6981941e-02, -2.0635496e-03, ...,
#          2.4285305e-02, -6.1613005e-03, -7.0992005e-03]], dtype=float32)

# %%
queries = []
for address in query_sents:
    address_number, street_name = address_parser(address)
    # another ineffiecinet encoding, but find for how small the dataset is
    queries.append([address, address_number, street_name, model.encode(street_name)])

print(len(queries))
# Out:
# 2024

# %%
data = []
for query_address, query_address_number, query_street_name, query_embedding in queries:
    filtered_corpus = corpus_dict[address_number]
    filtered_corpus_embeddings = filtered_corpus['embeddings']
    raw_matches = semantic_search(query_embedding, filtered_corpus_embeddings, top_k=3)
    row = [query_address]
    for val in raw_matches[0]:
        # try:
        row.extend([filtered_corpus['street_names'][val['corpus_id']], val['score']])
        # except KeyError:
        #     import pdb; pdb.set_trace()

    data.append(row)

# %%
matches_df = pd.DataFrame(data)

# %%
matches_df.sort_values(by=2, ascending=False).head(25)
# Out:
#                 0        1    2              3         4             5  \
# 1012  531 MAIN ST  main st  1.0  jones dock rd  0.615593  bear pond rd
# 1374  498 MAIN ST  main st  1.0  jones dock rd  0.615593  bear pond rd
# 981    75 MAIN ST  main st  1.0  jones dock rd  0.615593  bear pond rd
# 161   600 MAIN ST  main st  1.0  jones dock rd  0.615593  bear pond rd
# 1088  399 MAIN ST  main st  1.0  jones dock rd  0.615593  bear pond rd
# 137   602 MAIN ST  main st  1.0  jones dock rd  0.615593  bear pond rd
# 1252  516 MAIN ST  main st  1.0  jones dock rd  0.615593  bear pond rd
# 1257  567 MAIN ST  main st  1.0  jones dock rd  0.615593  bear pond rd
# 1260  582 MAIN ST  main st  1.0  jones dock rd  0.615593  bear pond rd
# 1341  413 MAIN ST  main st  1.0  jones dock rd  0.615593  bear pond rd
# 1343  485 MAIN ST  main st  1.0  jones dock rd  0.615593  bear pond rd
# 1345  449 MAIN ST  main st  1.0  jones dock rd  0.615593  bear pond rd
# 1347  601 MAIN ST  main st  1.0  jones dock rd  0.615593  bear pond rd
# 1348  501 MAIN ST  main st  1.0  jones dock rd  0.615593  bear pond rd
# 1349  491 MAIN ST  main st  1.0  jones dock rd  0.615593  bear pond rd
# 1350  515 MAIN ST  main st  1.0  jones dock rd  0.615593  bear pond rd
# 1351  499 MAIN ST  main st  1.0  jones dock rd  0.615593  bear pond rd
# 1352  523 MAIN ST  main st  1.0  jones dock rd  0.615593  bear pond rd
# 1354  537 MAIN ST  main st  1.0  jones dock rd  0.615593  bear pond rd
# 1355  606 MAIN ST  main st  1.0  jones dock rd  0.615593  bear pond rd
# 1360  604 MAIN ST  main st  1.0  jones dock rd  0.615593  bear pond rd
# 1362  599 MAIN ST  main st  1.0  jones dock rd  0.615593  bear pond rd
# 1363  518 MAIN ST  main st  1.0  jones dock rd  0.615593  bear pond rd
# 1364  520 MAIN ST  main st  1.0  jones dock rd  0.615593  bear pond rd
# 1365  530 MAIN ST  main st  1.0  jones dock rd  0.615593  bear pond rd
#
#              6
# 1012  0.608755
# 1374  0.608755
# 981   0.608755
# 161   0.608755
# 1088  0.608755
# 137   0.608755
# 1252  0.608755
# 1257  0.608755
# 1260  0.608755
# 1341  0.608755
# 1343  0.608755
# 1345  0.608755
# 1347  0.608755
# 1348  0.608755
# 1349  0.608755
# 1350  0.608755
# 1351  0.608755
# 1352  0.608755
# 1354  0.608755
# 1355  0.608755
# 1360  0.608755
# 1362  0.608755
# 1363  0.608755
# 1364  0.608755
# 1365  0.608755

# %%
matches_df.to_csv(DATA_DIR / 'processed' / 'match_df.csv')

# %%
corpus_dict['5322']['street_names']
# Out:
# ['route 30']

# %%
queries[1749]
# Out:
# ['5322 VT ROUTE 30',
#  '5322',
#  'vt route 30',
#  array([-2.19753925e-02, -3.74619812e-02, -1.78094872e-03,  3.73787880e-02,
#         -1.11582074e-02, -1.52974641e-02, -2.75730472e-02,  1.95965283e-02,
#         -1.11596137e-02, -2.26446446e-02,  8.63526464e-02,  1.19229276e-02,
#          5.60440086e-02,  8.43168870e-02,  3.83202098e-02, -3.26166004e-02,
